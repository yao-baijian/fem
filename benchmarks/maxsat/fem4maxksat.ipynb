# %%
from fem4maxksat import *

# %% [markdown]
# ## MaxSAT 2016 competition benchmarking

# %%
# example
instance = 's2v140c2000-1'  
device = 'cuda:1'
main(instance, device)
# Out:
# Reading file: ./ms_random_combine/s2v140c2000-1.cnf
# seed:  384
# minimum found by gradmfa: 298.0,
# elapsed time: 0.04973432794213295 seconds.
# mean: 298.05999755859375

# %%
instances  = sorted(os.listdir('./ms_random_combine'))  # reading all instances
device = 'cuda:1'
for instance in instances:
    main(instance, device)
# Out:
# Reading file: ./ms_random_combine/HG-3SAT-V250-C1000-1.cnf
# seed:  138
# minimum found by gradmfa: 7.0,
# elapsed time: 0.07798592373728752 seconds.
# mean: 11.0
# Reading file: ./ms_random_combine/HG-3SAT-V250-C1000-10.cnf
# seed:  335
# minimum found by gradmfa: 7.0,
# elapsed time: 0.07666455581784248 seconds.
# mean: 11.479999542236328
# Reading file: ./ms_random_combine/HG-3SAT-V250-C1000-100.cnf
# seed:  150
# minimum found by gradmfa: 8.0,
# elapsed time: 0.07653869688510895 seconds.
# mean: 11.899999618530273
# Reading file: ./ms_random_combine/HG-3SAT-V250-C1000-11.cnf
# seed:  331
# minimum found by gradmfa: 7.0,
# elapsed time: 0.07709219679236412 seconds.
# mean: 11.179999351501465
# Reading file: ./ms_random_combine/HG-3SAT-V250-C1000-12.cnf
# seed:  387
# minimum found by gradmfa: 7.0,
# elapsed time: 0.07692654803395271 seconds.
# mean: 12.179999351501465
# Reading file: ./ms_random_combine/HG-3SAT-V250-C1000-13.cnf
# seed:  16
# minimum found by gradmfa: 6.0,
# ...
